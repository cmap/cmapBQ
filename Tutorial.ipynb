# %%
import pandas as pd
import os
from google.cloud import bigquery
import cmapBQ.query as cmap_query
from cmapPy.pandasGEXpress.write_gctx import write as write_gctx

#viewing
#import qgrid


# Set up credentials
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'cmap-big-table-bd0276aaff22.json'
bq_client = bigquery.Client()

# %%
moas = cmap_query.list_cmap_moas(bq_client)
display(moas)
# Out:
#                                       moa
# 0         Nitric oxide synthase inhibitor
# 1                            AP inhibitor
# 2                           PKA inhibitor
# 3                    ATM kinase inhibitor
# 4                    Insulin secretagogue
# ..                                    ...
# 702                  ATR kinase inhibitor
# 703                  Dystrophin stimulant
# 704           Serotonin release inhibitor
# 705        Fructose biphosphate inhibitor
# 706  Voltage-gated calcium channel ligand
#
# [707 rows x 1 columns]

# %%
brom_inhib = cmap_query.cmap_compounds(client=bq_client, moa='Bromodomain inhibitor')

# %%
display(brom_inhib)
# Out:
#          pert_id  cmap_name target                    moa  \
# 0  BRD-K08109215  I-BET-762   BRD4  Bromodomain inhibitor
# 1  BRD-K08109215  I-BET-762   BRD3  Bromodomain inhibitor
# 2  BRD-K08109215  I-BET-762   BRD2  Bromodomain inhibitor
#
#                                     canonical_smiles  \
# 0  CCNC(=O)C[C@@H]1N=C(c2ccc(Cl)cc2)c2cc(OC)ccc2-...
# 1  CCNC(=O)C[C@@H]1N=C(c2ccc(Cl)cc2)c2cc(OC)ccc2-...
# 2  CCNC(=O)C[C@@H]1N=C(c2ccc(Cl)cc2)c2cc(OC)ccc2-...
#
#                      inchi_key compound_aliases
# 0  AAAQFGUYHFJNHI-SFHVURJKSA-N      GSK-525762A
# 1  AAAQFGUYHFJNHI-SFHVURJKSA-N      GSK-525762A
# 2  AAAQFGUYHFJNHI-SFHVURJKSA-N      GSK-525762A

# %% [markdown]
# <div style="font-size: 12pt;line-height:30px">
#
# In another example, we can query the dataset to look for all available gene targets using list_cmap_targets(). From this list of targets, we will see if our desired target **'CDK1'** is witin the database.

# %%
targets = cmap_query.list_cmap_targets(bq_client)
display(targets)
# Out:
#       target
# 0       BCL2
# 1      KCNH2
# 2     CYP2C9
# 3       GLRB
# 4      STAT3
# ..       ...
# 935   POLR2A
# 936  CYP11B2
# 937    ADCY2
# 938    SENP2
# 939     USP2
#
# [940 rows x 1 columns]

# %%
'CDK1' in targets.target.unique()
# Out:
# True

# %% [markdown]
# <div style="font-size: 12pt;line-height:30px">
#
# If the desired target is in the database, we can then query the compound table to get information about what compounds affect the CDK1 target.

# %%
CDK1_cps = cmap_query.cmap_compounds(client=bq_client, target='CDK1')
display(CDK1_cps)
# Out:
#           pert_id               cmap_name target  \
# 0   BRD-K14560436                   TG-02   CDK1
# 1   BRD-K14560436                   TG-02   CDK1
# 2   BRD-K14560436                   TG-02   CDK1
# 3   BRD-K13390322                 AT-7519   CDK1
# 4   BRD-K13390322                 AT-7519   CDK1
# 5   BRD-K78373679                 Ro-3306   CDK1
# 6   BRD-K35687265                ON-01910   CDK1
# 7   BRD-K79090631               CGP-60474   CDK1
# 8   BRD-K87909389               alvocidib   CDK1
# 9   BRD-K17894950               indirubin   CDK1
# 10  BRD-K17894950               indirubin   CDK1
# 11  BRD-K53959060               indirubin   CDK1
# 12  BRD-K53959060               indirubin   CDK1
# 13  BRD-K62814476              BMS-265246   CDK1
# 14  BRD-K31268420              NSC-693868   CDK1
# 15  BRD-K31268420              NSC-693868   CDK1
# 16  BRD-K87932577              NSC-693868   CDK1
# 17  BRD-K87932577              NSC-693868   CDK1
# 18  BRD-K64800655              PHA-793887   CDK1
# 19  BRD-K60997853              PHA-848125   CDK1
# 20  BRD-K60997853              PHA-848125   CDK1
# 21  BRD-K13662825              dinaciclib   CDK1
# 22  BRD-K82731415              olomoucine   CDK1
# 23  BRD-K11636097             JNJ-7706621   CDK1
# 24  BRD-K37312348             kenpaullone   CDK1
# 25  BRD-K37312348             kenpaullone   CDK1
# 26  BRD-K50836978            purvalanol-a   CDK1
# 27  BRD-K50836978            purvalanol-a   CDK1
# 28  BRD-K71726959           BRD-K71726959   CDK1
# 29  BRD-K03273112        1-azakenpaullone   CDK1
# 30  BRD-K07762753       aminopurvalanol-a   CDK1
# 31  BRD-K07762753       aminopurvalanol-a   CDK1
# 32  BRD-K45293975  7-hydroxystaurosporine   CDK1
# 33  BRD-K45293975  7-hydroxystaurosporine   CDK1
# 34  BRD-K45293975  7-hydroxystaurosporine   CDK1
#
#                                  moa  \
# 0                      JAK inhibitor
# 1                      CDK inhibitor
# 2                     FLT3 inhibitor
# 3                      CDK inhibitor
# 4               Cell cycle inhibitor
# 5                      CDK inhibitor
# 6                      PLK inhibitor
# 7                      CDK inhibitor
# 8                      CDK inhibitor
# 9                      CDK inhibitor
# 10                   GSK-3 inhibitor
# 11                     CDK inhibitor
# 12                   GSK-3 inhibitor
# 13                     CDK inhibitor
# 14                     CDK inhibitor
# 15                   GSK-3 inhibitor
# 16                     CDK inhibitor
# 17                   GSK-3 inhibitor
# 18                     CDK inhibitor
# 19  Growth factor receptor inhibitor
# 20                     CDK inhibitor
# 21                     CDK inhibitor
# 22                     CDK inhibitor
# 23                     CDK inhibitor
# 24                     CDK inhibitor
# 25                   GSK-3 inhibitor
# 26                    DYRK inhibitor
# 27                     CDK inhibitor
# 28                     CDK inhibitor
# 29                   GSK-3 inhibitor
# 30         Tyrosine kinase inhibitor
# 31                     CDK inhibitor
# 32                     CDK inhibitor
# 33                     CHK inhibitor
# 34                     PKC inhibitor
#
#                                      canonical_smiles  \
# 0        CN1CC=CCCOc2cccc(c2)-c2ccnc(Nc3cccc(C1)c3)n2
# 1        CN1CC=CCCOc2cccc(c2)-c2ccnc(Nc3cccc(C1)c3)n2
# 2        CN1CC=CCCOc2cccc(c2)-c2ccnc(Nc3cccc(C1)c3)n2
# 3        Clc1cccc(Cl)c1C(=O)Nc1c[nH]nc1C(=O)NC1CCNCC1
# 4        Clc1cccc(Cl)c1C(=O)Nc1c[nH]nc1C(=O)NC1CCNCC1
# 5              O=C1N=C(NCc2cccs2)SC1=C/c1ccc2ncccc2c1
# 6   COc1cc(OC)c(C=CS(=O)(=O)Cc2ccc(OC)c(NCC=O)c2)c...
# 7              OCCCNc1cc(ccn1)c2ccnc(Nc3cccc(Cl)c3)n2
# 8   CN1CC[C@@H]([C@H](O)C1)c1c(O)cc(O)c2c1oc(cc2=O...
# 9                     O=C1Nc2ccccc2C1=C1Nc2ccccc2C1=O
# 10                    O=C1Nc2ccccc2C1=C1Nc2ccccc2C1=O
# 11               ON=C1C(=C2C(=O)Nc3ccccc23)Nc4ccccc14
# 12               ON=C1C(=C2C(=O)Nc3ccccc23)Nc4ccccc14
# 13        CCCCOc1c(cnc2[nH]ncc12)C(=O)c1c(F)cc(C)cc1F
# 14                            Nc1nnc2[nH]c3ccccc3nc12
# 15                            Nc1nnc2[nH]c3ccccc3nc12
# 16                            Nc1n[nH]c2nc3ccccc3nc12
# 17                            Nc1n[nH]c2nc3ccccc3nc12
# 18  CC(C)CC(=O)Nc1n[nH]c2c1CN(C(=O)C1CCN(C)CC1)C2(C)C
# 19  CNC(=O)c1nn(C)c-2c1C(C)(C)Cc1cnc(Nc3ccc(cc3)N3...
# 20  CNC(=O)c1nn(C)c-2c1C(C)(C)Cc1cnc(Nc3ccc(cc3)N3...
# 21  CCc1cnn2c(NCc3ccc[n+]([O-])c3)cc(nc12)N1CCCC[C...
# 22                   Cn1cnc2c(NCc3ccccc3)nc(NCCO)nc12
# 23   Nc1nc(Nc2ccc(cc2)S(N)(=O)=O)nn1C(=O)c1c(F)cccc1F
# 24            Brc1ccc2[nH]c-3c(CC(=O)Nc4ccccc-34)c2c1
# 25            Brc1ccc2[nH]c-3c(CC(=O)Nc4ccccc-34)c2c1
# 26  CC(C)[C@H](CO)Nc1nc(Nc2cccc(Cl)c2)c2ncn(C(C)C)...
# 27  CC(C)[C@H](CO)Nc1nc(Nc2cccc(Cl)c2)c2ncn(C(C)C)...
# 28               CC(C)n1cnc2c(NCc3ccccc3)nc(NCCO)nc12
# 29            Brc1ccc2[nH]c-3c(CC(=O)Nc4cccnc-34)c2c1
# 30  CC(C)[C@H](CO)Nc1nc(Nc2cc(N)cc(Cl)c2)c2ncn(C(C...
# 31  CC(C)[C@H](CO)Nc1nc(Nc2cc(N)cc(Cl)c2)c2ncn(C(C...
# 32  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
# 33  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
# 34  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
#
#                       inchi_key        compound_aliases
# 0   VXBAJLGYBMTJCY-NSCUHMNNSA-N                    None
# 1   VXBAJLGYBMTJCY-NSCUHMNNSA-N                    None
# 2   VXBAJLGYBMTJCY-NSCUHMNNSA-N                    None
# 3   OVPNQJVDAFNBDN-UHFFFAOYSA-N                    None
# 4   OVPNQJVDAFNBDN-UHFFFAOYSA-N                    None
# 5   XOLMRFUGOINFDQ-YBEGLDIGSA-N                 RO-3306
# 6   POSHWWRILMRTTE-JXMROGBWSA-N                    None
# 7   IYNDTACKOAXKBJ-UHFFFAOYSA-N                    None
# 8   BIIVYFLTOXDAOV-YVEFUNNKSA-N                    None
# 9   CRDNMYFJWFXOCH-YPKPFQOOSA-N                    None
# 10  CRDNMYFJWFXOCH-YPKPFQOOSA-N                    None
# 11  HBDSHCUSXQATPO-UHFFFAOYSA-N                    None
# 12  HBDSHCUSXQATPO-UHFFFAOYSA-N                    None
# 13  SCFMWQIQBVZOQR-UHFFFAOYSA-N                    None
# 14  DWHVZCLBMTZRQM-UHFFFAOYSA-N                    None
# 15  DWHVZCLBMTZRQM-UHFFFAOYSA-N                    None
# 16  DWHVZCLBMTZRQM-UHFFFAOYSA-N                    None
# 17  DWHVZCLBMTZRQM-UHFFFAOYSA-N                    None
# 18  HUXYBQXJVXOMKX-UHFFFAOYSA-N                    None
# 19  RXZMYLDMFYNEIM-UHFFFAOYSA-N                    None
# 20  RXZMYLDMFYNEIM-UHFFFAOYSA-N                    None
# 21  PIMQWRZWLQKKBJ-SFHVURJKSA-N                    None
# 22  GTVPOLSIJWJJNY-UHFFFAOYSA-N                    None
# 23  KDKUVYLMPJIGKA-UHFFFAOYSA-N                    None
# 24  QQUXFYAWXPMDOE-UHFFFAOYSA-N                    None
# 25  QQUXFYAWXPMDOE-UHFFFAOYSA-N                    None
# 26  PMXCMJLOPOFPBT-HNNXBMFYSA-N                    None
# 27  PMXCMJLOPOFPBT-HNNXBMFYSA-N                    None
# 28  WHDJEAZLMYPLGL-UHFFFAOYSA-N                    None
# 29  NTSBZVCEIVPKBJ-UHFFFAOYSA-N        1-AZAKENPAULLONE
# 30  RAMROQQYRRQPDL-HNNXBMFYSA-N                    None
# 31  RAMROQQYRRQPDL-HNNXBMFYSA-N                    None
# 32  PBCZSGKMGDDXIJ-KRUBCLEUSA-N  7-HYDROXYSTAUROSPORINE
# 33  PBCZSGKMGDDXIJ-KRUBCLEUSA-N  7-HYDROXYSTAUROSPORINE
# 34  PBCZSGKMGDDXIJ-KRUBCLEUSA-N  7-HYDROXYSTAUROSPORINE

# %% [markdown]
# <div style="font-size: 12pt;line-height:30px">
#
# Lets take the first 10 compounds and see how many signatures are available for those compounds. We can pass a list of compounds to the **cmap_sig function**, which then queries the dataset for compounds that match.

# %%
CDK1_cps = CDK1_cps.pert_id.unique()

# %%
CDK1_cps[1:10]
# Out:
# array(['BRD-K13390322', 'BRD-K78373679', 'BRD-K35687265', 'BRD-K79090631',
#        'BRD-K87909389', 'BRD-K17894950', 'BRD-K53959060', 'BRD-K62814476',
#        'BRD-K31268420'], dtype=object)

# %%
CDK1_siginfo = cmap_query.cmap_sig(bq_client, pert_id=list(CDK1_cps))

# %%
CDK1_siginfo.columns
# Out:
# Index(['bead_batch', 'nearest_dose', 'pert_dose', 'pert_dose_unit',
#        'pert_idose', 'pert_itime', 'pert_time', 'pert_time_unit',
#        'cell_mfc_name', 'pert_mfc_id', 'nsample', 'cc_q75', 'ss_ngene', 'tas',
#        'pct_self_rank_q25', 'wt', 'median_recall_rank_spearman',
#        'median_recall_rank_wtcs_50', 'median_recall_score_spearman',
#        'median_recall_score_wtcs_50', 'batch_effect_tstat',
#        'batch_effect_tstat_pct', 'is_hiq', 'qc_pass', 'pert_id', 'sig_id',
#        'pert_iname', 'pert_type', 'cell_iname', 'id', 'det_wells',
#        'det_plates', 'distill_ids', 'distil_ids', 'build_name'],
#       dtype='object')

# %% [markdown]
# <div style="font-size: 12pt;line-height:30px">
#
#
# The siginfo file provides information on the conditions for each experiment such as compound, dose, timepoint, cell line, and more.
#
# The table also includes information regarding the signal strength and replicate correlation of the compound. The `distil_tas` contains the signatures Transcriptional Activity Score (TAS) which is an aggregate measure of strength and reproducibilty.  [More information about signature quality metrics can be found on Connectopedia](https://clue.io/connectopedia/signature_quality_metrics)

# %%
print("Time points:\n {}".format(CDK1_siginfo.pert_itime.unique()))
print("Doses: \n {}".format(CDK1_siginfo.pert_idose.unique()))
# Out:
# Time points:
#  ['3 h' '6 h' '12 h' '24 h' '48 h' '4 h']
# Doses:
#  ['10 uM' '1.11 uM' '3.33 uM' '0.37 uM' '0.12 uM' '0.04 uM' '2.22 uM'
#  '0.74 uM' '0.01 uM' '0.08 uM' '0.03 uM' '0.25 uM' '0.125 uM' '0.66 uM'
#  '0.002 uM' '0.004 uM' '4 uM' '20 uM' '12 uM' '30 uM' '100 uM' '2.5 uM'
#  '0.63 uM' '0.16 uM' '15 uM' '1.67 uM' '0.5 uM' '0.2 uM' '0.06 uM'
#  '125 uM' '50 uM' '12.5 uM']

# %%
filtered_CDK1 = CDK1_siginfo.loc[
    (CDK1_siginfo.pert_idose == '10 uM' ) & 
    (CDK1_siginfo.pert_itime == '24 h' )
]
display(filtered_CDK1)
# Out:
#      bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose pert_itime  \
# 11          b33          10.0       10.0             uM      10 uM       24 h
# 14          b33          10.0       10.0             uM      10 uM       24 h
# 24          b19          10.0       10.0             uM      10 uM       24 h
# 28          b19          10.0       10.0             uM      10 uM       24 h
# 31          b17          10.0       10.0             uM      10 uM       24 h
# ...         ...           ...        ...            ...        ...        ...
# 4193         b3          10.0       10.0             uM      10 uM       24 h
# 4200         b3          10.0       10.0             uM      10 uM       24 h
# 4201       f1b6          10.0       10.0             uM      10 uM       24 h
# 4215         b4          10.0       10.0             uM      10 uM       24 h
# 4218         b3          10.0       10.0             uM      10 uM       24 h
#
#       pert_time pert_time_unit     cell_mfc_name    pert_mfc_id  ...  \
# 11         24.0              h         MCF10A.WT  BRD-K14560436  ...
# 14         24.0              h  MCF10A.PIK3CA.HH  BRD-K14560436  ...
# 24         24.0              h              A549  BRD-K13390322  ...
# 28         24.0              h             HEPG2  BRD-K13390322  ...
# 31         24.0              h             SKBR3  BRD-K13390322  ...
# ...         ...            ...               ...            ...  ...
# 4193       24.0              h              HA1E  BRD-K07762753  ...
# 4200       24.0              h            HCC515  BRD-K07762753  ...
# 4201       24.0              h              A549  BRD-K07762753  ...
# 4215       24.0              h              MCF7  BRD-K07762753  ...
# 4218       24.0              h               PC3  BRD-K07762753  ...
#
#                                            sig_id         pert_iname  \
# 11                       LCP001_MCF10A.WT_24H:A16              TG-02
# 14                LCP001_MCF10A.PIK3CA.HH_24H:A16              TG-02
# 24                            LJP006_A549_24H:K01            AT-7519
# 28                           LJP006_HEPG2_24H:K01            AT-7519
# 31                           LJP006_SKBR3_24H:K01            AT-7519
# ...                                           ...                ...
# 4193    CPC002_HA1E_24H:BRD-K07762753-001-02-8:10  aminopurvalanol-a
# 4200  CPC002_HCC515_24H:BRD-K07762753-001-02-8:10  aminopurvalanol-a
# 4201    CPC016_A549_24H:BRD-K07762753-001-02-8:10  aminopurvalanol-a
# 4215    CPC016_MCF7_24H:BRD-K07762753-001-02-8:10  aminopurvalanol-a
# 4218     CPC002_PC3_24H:BRD-K07762753-001-02-8:10  aminopurvalanol-a
#
#       pert_type  cell_iname    id det_wells  \
# 11       trt_cp      MCF10A  None       A16
# 14       trt_cp      MCF10A  None       A16
# 24       trt_cp        A549  None       K01
# 28       trt_cp       HEPG2  None       K01
# 31       trt_cp       SKBR3  None       K01
# ...         ...         ...   ...       ...
# 4193     trt_cp        HA1E  None       J13
# 4200     trt_cp      HCC515  None       J13
# 4201     trt_cp        A549  None       O17
# 4215     trt_cp        MCF7  None       O17
# 4218     trt_cp         PC3  None       J13
#
#                                              det_plates  distill_ids  \
# 11    LCP001_MCF10A.WT_24H_X1.A2_B33|LCP001_MCF10A.W...         None
# 14    LCP001_MCF10A.PIK3CA.HH_24H_X1_B33|LCP001_MCF1...         None
# 24                               LJP006_A549_24H_X3_B19         None
# 28                              LJP006_HEPG2_24H_X1_B19         None
# 31                              LJP006_SKBR3_24H_X2_B17         None
# ...                                                 ...          ...
# 4193  CPC002_HA1E_24H_X1_B3_DUO52HI53LO|CPC002_HA1E_...         None
# 4200  CPC002_HCC515_24H_X1_B3_DUO52HI53LO|CPC002_HCC...         None
# 4201  CPC016_A549_24H_X1_F1B6_DUO52HI53LO|CPC016_A54...         None
# 4215  CPC016_MCF7_24H_X2_B4_DUO52HI53LO|CPC016_MCF7_...         None
# 4218  CPC002_PC3_24H_X1_B3_DUO52HI53LO|CPC002_PC3_24...         None
#
#                                              distil_ids  build_name
# 11    LCP001_MCF10A.WT_24H_X1.A2_B33:A16|LCP001_MCF1...        None
# 14    LCP001_MCF10A.PIK3CA.HH_24H_X1_B33:A16|LCP001_...        None
# 24                           LJP006_A549_24H_X3_B19:K01        None
# 28                          LJP006_HEPG2_24H_X1_B19:K01        None
# 31                          LJP006_SKBR3_24H_X2_B17:K01        None
# ...                                                 ...         ...
# 4193  CPC002_HA1E_24H_X1_B3_DUO52HI53LO:J13|CPC002_H...        None
# 4200  CPC002_HCC515_24H_X1_B3_DUO52HI53LO:J13|CPC002...        None
# 4201  CPC016_A549_24H_X1_F1B6_DUO52HI53LO:O17|CPC016...        None
# 4215  CPC016_MCF7_24H_X2_B4_DUO52HI53LO:O17|CPC016_M...        None
# 4218  CPC002_PC3_24H_X1_B3_DUO52HI53LO:J13|CPC002_PC...        None
#
# [749 rows x 35 columns]

# %% [markdown]
# <div style="font-size: 12pt;line-height:30px">
#
# From this table if we want the numerical data, we can extract the sig_ids and use them to query Level 5 database

# %%
CDK1_sig_ids = list(filtered_CDK1.sig_id.unique())

# %%
Level5_table = 'cmap-big-table.cmap_lincs_public_views.L1000_Level5'
CDK1_data = cmap_query.cmap_matrix(bq_client, table=Level5_table, cid= list(CDK1_sig_ids[0:10]))
# Out:
# Running query... (1/1)
# Pandas read_gbq may not be installed... Running query but no progress indicator available.
# Pivoting Dataframes to GCT objects
# Multiprocessing failed, pivoting chunks in series...
# Pivoting... (1/1)
# Complete

# %%
CDK1_data.data_df
# Out:
# cid    CPC013_VCAP_24H:BRD-K13390322-001-01-4:10  \
# rid
# 10                                        1.1886
# 100                                       1.3340
# 1000                                      2.2110
# 10000                                     1.2205
# 10001                                     1.3614
# ...                                          ...
# 9990                                      3.4672
# 9991                                      2.9928
# 9992                                      1.0733
# 9993                                     -1.0164
# 9997                                      2.3810
#
# cid    LCP001_MCF10A.PIK3CA.HH_24H:A16  LCP001_MCF10A.WT_24H:A16  \
# rid
# 10                            3.239779                  5.298019
# 100                           2.939360                  3.774793
# 1000                          0.667310                  0.406999
# 10000                         0.067272                  3.161932
# 10001                        -3.339724                 -4.977517
# ...                                ...                       ...
# 9990                          0.394020                  2.147964
# 9991                         -1.209314                 -1.152413
# 9992                          3.278781                  5.971286
# 9993                          1.170763                  2.313071
# 9997                         -0.654399                  0.951569
#
# cid    LJP006_A549_24H:K01  LJP006_HCC515_24H:K01  LJP006_HEPG2_24H:K01  \
# rid
# 10                  2.8715                 2.1157                1.6692
# 100                 2.2195                 2.1626                0.0923
# 1000               -1.9218                -0.9658               -0.8366
# 10000               0.0823                -0.2596               -0.1060
# 10001              -4.9531                -2.3165               -3.5381
# ...                    ...                    ...                   ...
# 9990                2.3118                 3.0469                3.9149
# 9991               -0.6147                -2.3920               -0.3553
# 9992                3.9968                 3.2692                3.4419
# 9993                1.1194                -0.3956                1.1507
# 9997               -0.2115                 0.5068               -1.9207
#
# cid    LJP006_HS578T_24H:K01  LJP006_MDAMB231_24H:K01  LJP006_SKBR3_24H:K01  \
# rid
# 10                    4.1007                   2.5273                5.1724
# 100                   0.0532                   1.8007                2.9654
# 1000                 -1.3488                   1.0057               -1.4546
# 10000                -0.6613                  -0.4124                2.0406
# 10001                -0.9235                  -2.3958               -2.1103
# ...                      ...                      ...                   ...
# 9990                  5.5874                   3.2962                5.1705
# 9991                 -0.7632                  -2.8745               -2.4230
# 9992                  4.3432                   3.0337                4.7231
# 9993                  1.8123                   0.7200                3.2820
# 9997                 -0.3416                   0.5494                1.0173
#
# cid    REP.A010_THP1_24H:H19
# rid
# 10                       0.0
# 100                      0.0
# 1000                     0.0
# 10000                    0.0
# 10001                    0.0
# ...                      ...
# 9990                     0.0
# 9991                     0.0
# 9992                     0.0
# 9993                     0.0
# 9997                     0.0
#
# [12328 rows x 10 columns]

# %%
#write_gctx(CDK1_data, filename)
