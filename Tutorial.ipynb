# %% [markdown]
# ## cmapBQ Tutorial
# <br>
# <div style="font-size: 10pt;line-height:20px;">
# This notebook is meant to show a few examples of exploring, selecting and retrieving data available within LINCS-CMap datasets from Google BigQuery.
#
# cmapBQ allow for targeted retrieval of relevant gene expression data from the massive resources provided by The Broad Institute and LINCS Project

# %% [markdown]
# ### Standard Imports

# %%
import os

import pandas as pd

# %% [markdown]
# ### Package imports

# %%
import cmapBQ.query as cmap_query
import cmapBQ.config as cmap_config

# Set up credentials
bq_client = cmap_config.get_bq_client()

# %% [markdown]
# <div style="font-size: 10pt;line-height:30px">
#
# Alternative method of authentication:

# %%
#from google.cloud import bigquery
#os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'cmap-big-table-bd0276aaff22.json'
#bq_client = bigquery.Client()

# %% [markdown]
# <div style="font-size: 10pt;line-height:30px">
#
# **[cmapPy](https://pypi.org/project/cmapPy/)** is a separate package that contains useful utilities for working with GCT(x), GRP data_types.

# %%
from cmapPy.pandasGEXpress.write_gctx import write as write_gctx

# %% [markdown]
# <div style="font-size: 14pt;line-height:30px;font-weight:bold">
# The data hosted on BigQuery is organized in a few separate tables.
#
# <div style="font-size: 10pt;line-height:18px;font-weight:normal">
#
# **compoundinfo:** Metadata for all unique compounds included in the data release. Each row contains information about
#
# **instinfo:**  <br> Sample level metadata includes information for each replicate
#
# **siginfo:**  <br> Signature (replicate collapsed) level 5 metadata
#
# **L1000 Level3:**  <br> Gene expression (GEX, Level 2) are normalized to invariant gene set curves and quantile normalized across each plate. Here, the data from each perturbagen treatment is referred to as a profile, experiment, or instance. Additional values for 11,350 additional genes not directly measured in the L10000 assay are inferred based on the normalized values for the 978 landmark genes.
#
#
# **L1000 Level4:**  <br> Z-scores for each gene based on Level 3 with respect to the entire plate population. This comparison of profiles to their appropriate population control generates a list of differentially expressed genes.
#
# **L1000 Level5:** <br> Replicate-collapsed z-score vectors based on Level 4. Replicate collapse generates one differential expression vector, which we term a signature. Connectivity analyses are performed on signatures.

# %%
moas = cmap_query.list_cmap_moas(bq_client)
display(moas)
# Out:
#                                              moa
# 0                                 PI3K inhibitor
# 1    Phosphoinositide dependent kinase inhibitor
# 2                                      Vitamin B
# 3                                 CAMP stimulant
# 4                                EPHB3 inhibitor
# ..                                           ...
# 701            Pyruvate kinase isozyme activator
# 702           Methylmalonyl CoA mutase stimulant
# 703           Structural glycoprotein antagonist
# 704        Hemozoin biocrystallization inhibitor
# 705  Glucose 6-phosphate dehydrogenase inhibitor
#
# [706 rows x 1 columns]

# %%
brom_inhib = cmap_query.cmap_compounds(client=bq_client, moa='Bromodomain inhibitor')

# %%
display(brom_inhib)
# Out:
#          pert_id  cmap_name target                    moa  \
# 0  BRD-K08109215  I-BET-762   BRD4  Bromodomain inhibitor
# 1  BRD-K08109215  I-BET-762   BRD3  Bromodomain inhibitor
# 2  BRD-K08109215  I-BET-762   BRD2  Bromodomain inhibitor
#
#                                     canonical_smiles  \
# 0  CCNC(=O)C[C@@H]1N=C(c2ccc(Cl)cc2)c2cc(OC)ccc2-...
# 1  CCNC(=O)C[C@@H]1N=C(c2ccc(Cl)cc2)c2cc(OC)ccc2-...
# 2  CCNC(=O)C[C@@H]1N=C(c2ccc(Cl)cc2)c2cc(OC)ccc2-...
#
#                      inchi_key compound_aliases
# 0  AAAQFGUYHFJNHI-SFHVURJKSA-N      GSK-525762A
# 1  AAAQFGUYHFJNHI-SFHVURJKSA-N      GSK-525762A
# 2  AAAQFGUYHFJNHI-SFHVURJKSA-N      GSK-525762A

# %% [markdown]
# <div style="font-size: 12pt;line-height:30px">
#
# In another example, we can query the dataset to look for all available gene targets using list_cmap_targets(). From this list of targets, we will see if our desired target **'CDK1'** is witin the database.

# %%
targets = cmap_query.list_cmap_targets(bq_client)
display(targets)
# Out:
#      target
# 0     NR1I3
# 1    PIK3CG
# 2     GSK3B
# 3      UGCG
# 4       PGR
# ..      ...
# 934    PPAT
# 935   ERBB3
# 936    HRH4
# 937    TLR4
# 938  TBXAS1
#
# [939 rows x 1 columns]

# %%
'CDK1' in targets.target.unique()
# Out:
# True

# %% [markdown]
# <div style="font-size: 12pt;line-height:30px">
#
# If the desired target is in the database, we can then query the compound table to get information about what compounds affect the CDK1 target.

# %%
CDK1_cpinfo = cmap_query.cmap_compounds(client=bq_client, target='CDK1', verbose=True)
display(CDK1_cpinfo)
# Out:
# Table:
#  cmap-big-table.broad_cmap_lincs_data.compoundinfo
# Query:
#  SELECT * FROM cmap-big-table.broad_cmap_lincs_data.compoundinfo WHERE target in UNNEST(['CDK1'])
#           pert_id               cmap_name target  \
# 0   BRD-K87909389               alvocidib   CDK1
# 1   BRD-K17894950               indirubin   CDK1
# 2   BRD-K17894950               indirubin   CDK1
# 3   BRD-K31268420              NSC-693868   CDK1
# 4   BRD-K87932577              NSC-693868   CDK1
# 5   BRD-K87932577              NSC-693868   CDK1
# 6   BRD-K31268420              NSC-693868   CDK1
# 7   BRD-K82731415              olomoucine   CDK1
# 8   BRD-K53959060               indirubin   CDK1
# 9   BRD-K53959060               indirubin   CDK1
# 10  BRD-K64800655              PHA-793887   CDK1
# 11  BRD-K79090631               CGP-60474   CDK1
# 12  BRD-K11636097             JNJ-7706621   CDK1
# 13  BRD-K13390322                 AT-7519   CDK1
# 14  BRD-K13390322                 AT-7519   CDK1
# 15  BRD-K13662825              dinaciclib   CDK1
# 16  BRD-K50836978            purvalanol-a   CDK1
# 17  BRD-K50836978            purvalanol-a   CDK1
# 18  BRD-K35687265                ON-01910   CDK1
# 19  BRD-K37312348             kenpaullone   CDK1
# 20  BRD-K37312348             kenpaullone   CDK1
# 21  BRD-K07762753       aminopurvalanol-a   CDK1
# 22  BRD-K07762753       aminopurvalanol-a   CDK1
# 23  BRD-K60997853              PHA-848125   CDK1
# 24  BRD-K60997853              PHA-848125   CDK1
# 25  BRD-K62814476              BMS-265246   CDK1
# 26  BRD-K14560436                   TG-02   CDK1
# 27  BRD-K14560436                   TG-02   CDK1
# 28  BRD-K14560436                   TG-02   CDK1
# 29  BRD-K71726959           BRD-K71726959   CDK1
# 30  BRD-K78373679                 Ro-3306   CDK1
# 31  BRD-K03273112        1-azakenpaullone   CDK1
# 32  BRD-K45293975  7-hydroxystaurosporine   CDK1
# 33  BRD-K45293975  7-hydroxystaurosporine   CDK1
# 34  BRD-K45293975  7-hydroxystaurosporine   CDK1
#
#                                  moa  \
# 0                      CDK inhibitor
# 1                      CDK inhibitor
# 2                    GSK-3 inhibitor
# 3                    GSK-3 inhibitor
# 4                    GSK-3 inhibitor
# 5                      CDK inhibitor
# 6                      CDK inhibitor
# 7                      CDK inhibitor
# 8                    GSK-3 inhibitor
# 9                      CDK inhibitor
# 10                     CDK inhibitor
# 11                     CDK inhibitor
# 12                     CDK inhibitor
# 13                     CDK inhibitor
# 14              Cell cycle inhibitor
# 15                     CDK inhibitor
# 16                    DYRK inhibitor
# 17                     CDK inhibitor
# 18                     PLK inhibitor
# 19                   GSK-3 inhibitor
# 20                     CDK inhibitor
# 21                     CDK inhibitor
# 22         Tyrosine kinase inhibitor
# 23                     CDK inhibitor
# 24  Growth factor receptor inhibitor
# 25                     CDK inhibitor
# 26                    FLT3 inhibitor
# 27                     JAK inhibitor
# 28                     CDK inhibitor
# 29                     CDK inhibitor
# 30                     CDK inhibitor
# 31                   GSK-3 inhibitor
# 32                     CHK inhibitor
# 33                     PKC inhibitor
# 34                     CDK inhibitor
#
#                                      canonical_smiles  \
# 0   CN1CC[C@@H]([C@H](O)C1)c1c(O)cc(O)c2c1oc(cc2=O...
# 1                     O=C1Nc2ccccc2C1=C1Nc2ccccc2C1=O
# 2                     O=C1Nc2ccccc2C1=C1Nc2ccccc2C1=O
# 3                             Nc1nnc2[nH]c3ccccc3nc12
# 4                             Nc1n[nH]c2nc3ccccc3nc12
# 5                             Nc1n[nH]c2nc3ccccc3nc12
# 6                             Nc1nnc2[nH]c3ccccc3nc12
# 7                    Cn1cnc2c(NCc3ccccc3)nc(NCCO)nc12
# 8                ON=C1C(=C2C(=O)Nc3ccccc23)Nc4ccccc14
# 9                ON=C1C(=C2C(=O)Nc3ccccc23)Nc4ccccc14
# 10  CC(C)CC(=O)Nc1n[nH]c2c1CN(C(=O)C1CCN(C)CC1)C2(C)C
# 11             OCCCNc1cc(ccn1)c2ccnc(Nc3cccc(Cl)c3)n2
# 12   Nc1nc(Nc2ccc(cc2)S(N)(=O)=O)nn1C(=O)c1c(F)cccc1F
# 13       Clc1cccc(Cl)c1C(=O)Nc1c[nH]nc1C(=O)NC1CCNCC1
# 14       Clc1cccc(Cl)c1C(=O)Nc1c[nH]nc1C(=O)NC1CCNCC1
# 15  CCc1cnn2c(NCc3ccc[n+]([O-])c3)cc(nc12)N1CCCC[C...
# 16  CC(C)[C@H](CO)Nc1nc(Nc2cccc(Cl)c2)c2ncn(C(C)C)...
# 17  CC(C)[C@H](CO)Nc1nc(Nc2cccc(Cl)c2)c2ncn(C(C)C)...
# 18  COc1cc(OC)c(C=CS(=O)(=O)Cc2ccc(OC)c(NCC=O)c2)c...
# 19            Brc1ccc2[nH]c-3c(CC(=O)Nc4ccccc-34)c2c1
# 20            Brc1ccc2[nH]c-3c(CC(=O)Nc4ccccc-34)c2c1
# 21  CC(C)[C@H](CO)Nc1nc(Nc2cc(N)cc(Cl)c2)c2ncn(C(C...
# 22  CC(C)[C@H](CO)Nc1nc(Nc2cc(N)cc(Cl)c2)c2ncn(C(C...
# 23  CNC(=O)c1nn(C)c-2c1C(C)(C)Cc1cnc(Nc3ccc(cc3)N3...
# 24  CNC(=O)c1nn(C)c-2c1C(C)(C)Cc1cnc(Nc3ccc(cc3)N3...
# 25        CCCCOc1c(cnc2[nH]ncc12)C(=O)c1c(F)cc(C)cc1F
# 26       CN1CC=CCCOc2cccc(c2)-c2ccnc(Nc3cccc(C1)c3)n2
# 27       CN1CC=CCCOc2cccc(c2)-c2ccnc(Nc3cccc(C1)c3)n2
# 28       CN1CC=CCCOc2cccc(c2)-c2ccnc(Nc3cccc(C1)c3)n2
# 29               CC(C)n1cnc2c(NCc3ccccc3)nc(NCCO)nc12
# 30             O=C1N=C(NCc2cccs2)SC1=C/c1ccc2ncccc2c1
# 31            Brc1ccc2[nH]c-3c(CC(=O)Nc4cccnc-34)c2c1
# 32  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
# 33  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
# 34  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
#
#                       inchi_key        compound_aliases
# 0   BIIVYFLTOXDAOV-YVEFUNNKSA-N                    None
# 1   CRDNMYFJWFXOCH-YPKPFQOOSA-N                    None
# 2   CRDNMYFJWFXOCH-YPKPFQOOSA-N                    None
# 3   DWHVZCLBMTZRQM-UHFFFAOYSA-N                    None
# 4   DWHVZCLBMTZRQM-UHFFFAOYSA-N                    None
# 5   DWHVZCLBMTZRQM-UHFFFAOYSA-N                    None
# 6   DWHVZCLBMTZRQM-UHFFFAOYSA-N                    None
# 7   GTVPOLSIJWJJNY-UHFFFAOYSA-N                    None
# 8   HBDSHCUSXQATPO-UHFFFAOYSA-N                    None
# 9   HBDSHCUSXQATPO-UHFFFAOYSA-N                    None
# 10  HUXYBQXJVXOMKX-UHFFFAOYSA-N                    None
# 11  IYNDTACKOAXKBJ-UHFFFAOYSA-N                    None
# 12  KDKUVYLMPJIGKA-UHFFFAOYSA-N                    None
# 13  OVPNQJVDAFNBDN-UHFFFAOYSA-N                    None
# 14  OVPNQJVDAFNBDN-UHFFFAOYSA-N                    None
# 15  PIMQWRZWLQKKBJ-SFHVURJKSA-N                    None
# 16  PMXCMJLOPOFPBT-HNNXBMFYSA-N                    None
# 17  PMXCMJLOPOFPBT-HNNXBMFYSA-N                    None
# 18  POSHWWRILMRTTE-JXMROGBWSA-N                    None
# 19  QQUXFYAWXPMDOE-UHFFFAOYSA-N                    None
# 20  QQUXFYAWXPMDOE-UHFFFAOYSA-N                    None
# 21  RAMROQQYRRQPDL-HNNXBMFYSA-N                    None
# 22  RAMROQQYRRQPDL-HNNXBMFYSA-N                    None
# 23  RXZMYLDMFYNEIM-UHFFFAOYSA-N                    None
# 24  RXZMYLDMFYNEIM-UHFFFAOYSA-N                    None
# 25  SCFMWQIQBVZOQR-UHFFFAOYSA-N                    None
# 26  VXBAJLGYBMTJCY-NSCUHMNNSA-N                    None
# 27  VXBAJLGYBMTJCY-NSCUHMNNSA-N                    None
# 28  VXBAJLGYBMTJCY-NSCUHMNNSA-N                    None
# 29  WHDJEAZLMYPLGL-UHFFFAOYSA-N                    None
# 30  XOLMRFUGOINFDQ-YBEGLDIGSA-N                 RO-3306
# 31  NTSBZVCEIVPKBJ-UHFFFAOYSA-N        1-AZAKENPAULLONE
# 32  PBCZSGKMGDDXIJ-KRUBCLEUSA-N  7-HYDROXYSTAUROSPORINE
# 33  PBCZSGKMGDDXIJ-KRUBCLEUSA-N  7-HYDROXYSTAUROSPORINE
# 34  PBCZSGKMGDDXIJ-KRUBCLEUSA-N  7-HYDROXYSTAUROSPORINE

# %% [markdown]
# <div style="font-size: 12pt;line-height:30px">
#
# Lets take the first 10 compounds and see how many signatures are available for those compounds. We can pass a list of compounds to the **cmap_sig function**, which then queries the dataset for compounds that match.

# %%
CDK1_cps = CDK1_cpinfo.pert_id.unique()

# %%
CDK1_cps[1:10]
# Out:
# array(['BRD-K17894950', 'BRD-K31268420', 'BRD-K87932577', 'BRD-K82731415',
#        'BRD-K53959060', 'BRD-K64800655', 'BRD-K79090631', 'BRD-K11636097',
#        'BRD-K13390322'], dtype=object)

# %%
CDK1_siginfo = cmap_query.cmap_sig(bq_client, pert_id=list(CDK1_cps), verbose=True)
# Out:
# Table:
#  cmap-big-table.cmap_lincs_public_views.siginfo
# Query:
#  SELECT * FROM cmap-big-table.cmap_lincs_public_views.siginfo WHERE pert_id in UNNEST(['BRD-K87909389', 'BRD-K17894950', 'BRD-K31268420', 'BRD-K87932577', 'BRD-K82731415', 'BRD-K53959060', 'BRD-K64800655', 'BRD-K79090631', 'BRD-K11636097', 'BRD-K13390322', 'BRD-K13662825', 'BRD-K50836978', 'BRD-K35687265', 'BRD-K37312348', 'BRD-K07762753', 'BRD-K60997853', 'BRD-K62814476', 'BRD-K14560436', 'BRD-K71726959', 'BRD-K78373679', 'BRD-K03273112', 'BRD-K45293975'])

# %%
CDK1_siginfo
# Out:
#      bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose pert_itime  \
# 0           b33         10.00   10.00000             uM       None        3 h
# 1           b33          1.11    1.11111             uM       None        3 h
# 2           b33          3.33    3.33333             uM       None        3 h
# 3           b33          1.11    1.11111             uM       None        6 h
# 4           b33          3.33    3.33333             uM       None        6 h
# ...         ...           ...        ...            ...        ...        ...
# 4255        b42          3.33    3.33000             uM       None       24 h
# 4256        b42          0.66    0.67000             uM       None       24 h
# 4257        b33          1.11    1.11111             uM       None       24 h
# 4258        b33          3.33    3.33333             uM       None       24 h
# 4259        b33          1.11    1.11111             uM       None       24 h
#
#       pert_time pert_time_unit     cell_mfc_name    pert_mfc_id  ...  \
# 0           3.0              h         MCF10A.WT  BRD-K14560436  ...
# 1           3.0              h         MCF10A.WT  BRD-K14560436  ...
# 2           3.0              h         MCF10A.WT  BRD-K14560436  ...
# 3           6.0              h         MCF10A.WT  BRD-K14560436  ...
# 4           6.0              h         MCF10A.WT  BRD-K14560436  ...
# ...         ...            ...               ...            ...  ...
# 4255       24.0              h       HAP1.PRKACA  BRD-K45293975  ...
# 4256       24.0              h       HAP1.PRKACA  BRD-K45293975  ...
# 4257       24.0              h  MCF10A.PIK3CA.HH  BRD-K45293975  ...
# 4258       24.0              h  MCF10A.PIK3CA.HH  BRD-K45293975  ...
# 4259       24.0              h    MCF10A.KRAS.HG  BRD-K45293975  ...
#
#                   pert_iname  pert_type  cell_iname  id  det_wells  \
# 0                      TG-02     trt_cp      MCF10A NaN        A16
# 1                      TG-02     trt_cp      MCF10A NaN        A18
# 2                      TG-02     trt_cp      MCF10A NaN        A17
# 3                      TG-02     trt_cp      MCF10A NaN        A18
# 4                      TG-02     trt_cp      MCF10A NaN        A17
# ...                      ...        ...         ...  ..        ...
# 4255  7-hydroxystaurosporine     trt_cp        HAP1 NaN        A13
# 4256  7-hydroxystaurosporine     trt_cp        HAP1 NaN        A14
# 4257  7-hydroxystaurosporine     trt_cp      MCF10A NaN        B24
# 4258  7-hydroxystaurosporine     trt_cp      MCF10A NaN        B23
# 4259  7-hydroxystaurosporine     trt_cp      MCF10A NaN        B24
#
#                                              det_plates  distill_ids  \
# 0     LCP001_MCF10A.WT_3H_X1.A2_B33|LCP001_MCF10A.WT...         None
# 1     LCP001_MCF10A.WT_3H_X1.A2_B33|LCP001_MCF10A.WT...         None
# 2     LCP001_MCF10A.WT_3H_X1.A2_B33|LCP001_MCF10A.WT...         None
# 3     LCP001_MCF10A.WT_6H_X1.A2_B33|LCP001_MCF10A.WT...         None
# 4     LCP001_MCF10A.WT_6H_X1.A2_B33|LCP001_MCF10A.WT...         None
# ...                                                 ...          ...
# 4255  MOAR018_HAP1.PRKACA_24H_X1_B42|MOAR018_HAP1.PR...         None
# 4256  MOAR018_HAP1.PRKACA_24H_X1_B42|MOAR018_HAP1.PR...         None
# 4257  LCP001_MCF10A.PIK3CA.HH_24H_X1_B33|LCP001_MCF1...         None
# 4258  LCP001_MCF10A.PIK3CA.HH_24H_X1_B33|LCP001_MCF1...         None
# 4259  LCP001_MCF10A.KRAS.HG_24H_X1.A2_B33|LCP001_MCF...         None
#
#                                              distil_ids  build_name  \
# 0     LCP001_MCF10A.WT_3H_X1.A2_B33:A16|LCP001_MCF10...        None
# 1     LCP001_MCF10A.WT_3H_X1.A2_B33:A18|LCP001_MCF10...        None
# 2     LCP001_MCF10A.WT_3H_X1.A2_B33:A17|LCP001_MCF10...        None
# 3     LCP001_MCF10A.WT_6H_X1.A2_B33:A18|LCP001_MCF10...        None
# 4     LCP001_MCF10A.WT_6H_X1.A2_B33:A17|LCP001_MCF10...        None
# ...                                                 ...         ...
# 4255  MOAR018_HAP1.PRKACA_24H_X1_B42:A13|MOAR018_HAP...        None
# 4256  MOAR018_HAP1.PRKACA_24H_X1_B42:A14|MOAR018_HAP...        None
# 4257  LCP001_MCF10A.PIK3CA.HH_24H_X1_B33:B24|LCP001_...        None
# 4258  LCP001_MCF10A.PIK3CA.HH_24H_X1_B33:B23|LCP001_...        None
# 4259  LCP001_MCF10A.KRAS.HG_24H_X1.A2_B33:B24|LCP001...        None
#
#       project_code
# 0              LCP
# 1              LCP
# 2              LCP
# 3              LCP
# 4              LCP
# ...            ...
# 4255          MOAR
# 4256          MOAR
# 4257           LCP
# 4258           LCP
# 4259           LCP
#
# [4260 rows x 36 columns]

# %% [markdown]
# <div style="font-size: 12pt;line-height:30px">
#
#
# The siginfo file provides information on the conditions for each experiment such as compound, dose, timepoint, cell line, and more.
#
# The table also includes information regarding the signal strength and replicate correlation of the compound. The `distil_tas` contains the signatures **Transcriptional Activity Score (TAS)** which is an aggregate measure of strength and reproducibilty.  [More information about signature quality metrics can be found on Connectopedia](https://clue.io/connectopedia/signature_quality_metrics)

# %%
print("Time points:\n {}".format(CDK1_siginfo.pert_itime.unique()))
print("Doses: \n {}".format(CDK1_siginfo.pert_idose.unique()))
# Out:
# Time points:
#  ['3 h' '6 h' '12 h' '24 h' '48 h' '4 h']
# Doses:
#  [None]

# %%
filtered_CDK1 = CDK1_siginfo.loc[
    (CDK1_siginfo.pert_dose == 10 ) & 
    (CDK1_siginfo.pert_itime == '24 h' )
]
display(filtered_CDK1[0:10])
# Out:
#    bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose pert_itime  \
# 9         b33          10.0       10.0             uM       None       24 h
# 13        b33          10.0       10.0             uM       None       24 h
# 24        b19          10.0       10.0             uM       None       24 h
# 30        b19          10.0       10.0             uM       None       24 h
# 31        b17          10.0       10.0             uM       None       24 h
# 38        b19          10.0       10.0             uM       None       24 h
# 39        b17          10.0       10.0             uM       None       24 h
# 41        b32          10.0       10.0             uM       None       24 h
# 53        b17          10.0       10.0             uM       None       24 h
# 63         b5          10.0       10.0             uM       None       24 h
#
#     pert_time pert_time_unit     cell_mfc_name    pert_mfc_id  ...  \
# 9        24.0              h         MCF10A.WT  BRD-K14560436  ...
# 13       24.0              h  MCF10A.PIK3CA.HH  BRD-K14560436  ...
# 24       24.0              h              A549  BRD-K13390322  ...
# 30       24.0              h             HEPG2  BRD-K13390322  ...
# 31       24.0              h             SKBR3  BRD-K13390322  ...
# 38       24.0              h            HCC515  BRD-K13390322  ...
# 39       24.0              h            HS578T  BRD-K13390322  ...
# 41       24.0              h              THP1  BRD-K13390322  ...
# 53       24.0              h          MDAMB231  BRD-K13390322  ...
# 63       24.0              h              VCAP  BRD-K13390322  ...
#
#     pert_iname  pert_type  cell_iname  id  det_wells  \
# 9        TG-02     trt_cp      MCF10A NaN        A16
# 13       TG-02     trt_cp      MCF10A NaN        A16
# 24     AT-7519     trt_cp        A549 NaN        K01
# 30     AT-7519     trt_cp       HEPG2 NaN        K01
# 31     AT-7519     trt_cp       SKBR3 NaN        K01
# 38     AT-7519     trt_cp      HCC515 NaN        K01
# 39     AT-7519     trt_cp      HS578T NaN        K01
# 41     AT-7519     trt_cp        THP1 NaN        H19
# 53     AT-7519     trt_cp    MDAMB231 NaN        K01
# 63     AT-7519     trt_cp        VCAP NaN        K04
#
#                                            det_plates  distill_ids  \
# 9   LCP001_MCF10A.WT_24H_X1.A2_B33|LCP001_MCF10A.W...         None
# 13  LCP001_MCF10A.PIK3CA.HH_24H_X1_B33|LCP001_MCF1...         None
# 24                             LJP006_A549_24H_X3_B19         None
# 30                            LJP006_HEPG2_24H_X1_B19         None
# 31                            LJP006_SKBR3_24H_X2_B17         None
# 38                           LJP006_HCC515_24H_X3_B19         None
# 39                           LJP006_HS578T_24H_X2_B17         None
# 41                           REP.A010_THP1_24H_X3_B32         None
# 53                         LJP006_MDAMB231_24H_X2_B17         None
# 63                  CPC013_VCAP_24H_X3_B5_DUO52HI53LO         None
#
#                                            distil_ids  build_name  \
# 9   LCP001_MCF10A.WT_24H_X1.A2_B33:A16|LCP001_MCF1...        None
# 13  LCP001_MCF10A.PIK3CA.HH_24H_X1_B33:A16|LCP001_...        None
# 24                         LJP006_A549_24H_X3_B19:K01        None
# 30                        LJP006_HEPG2_24H_X1_B19:K01        None
# 31                        LJP006_SKBR3_24H_X2_B17:K01        None
# 38                       LJP006_HCC515_24H_X3_B19:K01        None
# 39                       LJP006_HS578T_24H_X2_B17:K01        None
# 41                       REP.A010_THP1_24H_X3_B32:H19        None
# 53                     LJP006_MDAMB231_24H_X2_B17:K01        None
# 63              CPC013_VCAP_24H_X3_B5_DUO52HI53LO:K04        None
#
#     project_code
# 9            LCP
# 13           LCP
# 24           LJP
# 30           LJP
# 31           LJP
# 38           LJP
# 39           LJP
# 41           REP
# 53           LJP
# 63           CPC
#
# [10 rows x 36 columns]

# %% [markdown]
# <div style="font-size: 12pt;line-height:30px">
#
# From this table if we want the numerical data, we can extract the sig_ids and use them to query Level 5 database

# %%
CDK1_sig_ids = list(filtered_CDK1.sig_id.unique())

# %%
CDK1_data = cmap_query.cmap_matrix(bq_client, data_level='level5', cid=list(CDK1_siginfo.sig_id.unique()[0:1000]))
# Out:
# Running query ... (1/1)
# Pivoting Dataframes to GCT objects
# Pivoting... (1/1)
# Complete

# %%
CDK1_data.data_df
# Out:
# cid    CPC013_A375_6H:BRD-K13390322-001-01-4:10  \
# rid
# 10                                     1.185874
# 100                                    0.696834
# 1000                                  -1.083696
# 10000                                  0.222204
# 10001                                 -3.254283
# ...                                         ...
# 9990                                   0.176370
# 9991                                  -0.606921
# 9992                                   3.296041
# 9993                                   0.716135
# 9997                                  -0.855330
#
# cid    CPC013_A375_6H:BRD-K35687265-236-01-8:10  \
# rid
# 10                                    -0.755140
# 100                                    0.422637
# 1000                                   0.472077
# 10000                                  1.264480
# 10001                                 -0.499116
# ...                                         ...
# 9990                                   1.010904
# 9991                                  -0.430509
# 9992                                  -0.034924
# 9993                                   0.798054
# 9997                                  -0.459347
#
# cid    CPC013_A549_24H:BRD-K13390322-001-01-4:10  \
# rid
# 10                                      2.198585
# 100                                     1.202844
# 1000                                   -0.971127
# 10000                                   0.643960
# 10001                                  -2.736520
# ...                                          ...
# 9990                                    1.712255
# 9991                                    1.217269
# 9992                                    2.231316
# 9993                                    3.221704
# 9997                                   -0.009134
#
# cid    CPC013_A549_24H:BRD-K35687265-236-01-8:10  \
# rid
# 10                                      0.142736
# 100                                     0.205725
# 1000                                   -1.291404
# 10000                                   1.651972
# 10001                                   0.238186
# ...                                          ...
# 9990                                    1.358158
# 9991                                    0.161526
# 9992                                    1.897164
# 9993                                    2.097658
# 9997                                   -1.519783
#
# cid    CPC013_A549_6H:BRD-K13390322-001-01-4:10  \
# rid
# 10                                      0.65130
# 100                                    -0.24250
# 1000                                    0.86940
# 10000                                   0.56995
# 10001                                  -2.54485
# ...                                         ...
# 9990                                    0.91145
# 9991                                    0.65505
# 9992                                    1.09635
# 9993                                    0.55880
# 9997                                   -0.33535
#
# cid    CPC013_A549_6H:BRD-K35687265-236-01-8:10  \
# rid
# 10                                      1.04160
# 100                                     0.04610
# 1000                                    2.39490
# 10000                                   1.64155
# 10001                                   1.84870
# ...                                         ...
# 9990                                   -0.79630
# 9991                                    0.65290
# 9992                                   -1.42030
# 9993                                   -1.05370
# 9997                                   -0.99375
#
# cid    CPC013_ASC_24H:BRD-K13390322-001-01-4:10  \
# rid
# 10                                     1.119104
# 100                                    2.054602
# 1000                                  -0.554291
# 10000                                  1.611529
# 10001                                 -1.354021
# ...                                         ...
# 9990                                   1.329882
# 9991                                   0.299556
# 9992                                   1.546041
# 9993                                   0.749012
# 9997                                  -2.219423
#
# cid    CPC013_ASC_24H:BRD-K35687265-236-01-8:10  \
# rid
# 10                                     1.244991
# 100                                    0.284038
# 1000                                  -0.814638
# 10000                                 -0.252383
# 10001                                 -1.284102
# ...                                         ...
# 9990                                   1.829830
# 9991                                   1.488463
# 9992                                   1.177567
# 9993                                   1.368835
# 9997                                  -0.445080
#
# cid    CPC013_HA1E_6H:BRD-K13390322-001-01-4:10  \
# rid
# 10                                     1.342418
# 100                                    0.672675
# 1000                                  -0.728171
# 10000                                 -0.316395
# 10001                                 -2.195163
# ...                                         ...
# 9990                                   0.302232
# 9991                                   0.883985
# 9992                                   0.784149
# 9993                                   1.093000
# 9997                                  -0.213524
#
# cid    CPC013_HA1E_6H:BRD-K35687265-236-01-8:10  ...  REP.B010_THP1_24H:H20  \
# rid                                              ...
# 10                                     -0.24075  ...                -0.5165
# 100                                    -0.08910  ...                -1.4070
# 1000                                    0.90575  ...                 0.4894
# 10000                                   0.72670  ...                 1.1318
# 10001                                  -0.04860  ...                -0.6464
# ...                                         ...  ...                    ...
# 9990                                   -0.12655  ...                -0.7778
# 9991                                    1.96890  ...                 0.6310
# 9992                                   -1.65690  ...                -0.3122
# 9993                                   -1.55275  ...                 0.6351
# 9997                                   -0.69815  ...                -0.0888
#
# cid    REP.B010_THP1_24H:H21  REP.B010_THP1_24H:H22  REP.B010_THP1_24H:H23  \
# rid
# 10                    0.1779                 0.4730                -0.6473
# 100                  -0.0255                -1.3465                 0.0862
# 1000                 -0.8271                -0.3009                 0.5749
# 10000                -0.4356                -1.5301                -1.7060
# 10001                 0.5009                 1.8189                -0.4062
# ...                      ...                    ...                    ...
# 9990                 -0.7677                 1.5271                -0.2404
# 9991                 -0.5325                -0.5431                 0.7035
# 9992                 -0.1523                 1.3027                -0.4895
# 9993                  0.4447                -0.1789                -0.7176
# 9997                 -1.1151                -0.1177                -1.4017
#
# cid    REP.B010_THP1_24H:H24  REP.B010_YAPC_24H:H20  REP.B010_YAPC_24H:H21  \
# rid
# 10                    2.3583               -0.52375               -0.69800
# 100                  -0.5013               -1.18470                0.44690
# 1000                 -0.3269               -1.02605               -0.44180
# 10000                -0.4083               -1.03325               -0.33220
# 10001                 0.5950                1.31095                0.71035
# ...                      ...                    ...                    ...
# 9990                 -1.1305               -0.62705               -0.38080
# 9991                  0.3294                0.40080                1.50040
# 9992                  0.1480               -0.93155               -0.88985
# 9993                  1.4010                0.95080               -0.71990
# 9997                 -2.2333               -0.16745                0.97260
#
# cid    REP.B010_YAPC_24H:H22  REP.B010_YAPC_24H:H23  REP.B010_YAPC_24H:H24
# rid
# 10                   0.78370               -0.01310                0.93090
# 100                 -0.46790                0.14660               -0.66150
# 1000                -0.60815               -0.79565                0.96565
# 10000               -0.74380                0.04160               -0.72080
# 10001                1.19365               -0.65685               -0.12895
# ...                      ...                    ...                    ...
# 9990                 0.98915                1.74755                1.08035
# 9991                 0.53195               -1.02535               -1.03965
# 9992                -0.25435                1.26340                0.12340
# 9993                -0.76605               -0.51430                1.41545
# 9997                -0.49395                1.01595               -0.25280
#
# [12328 rows x 1000 columns]

# %%
#write_gctx(CDK1_data, filename)
